# %% [markdown]
# Programa 1 del examen: formula general y discriminante

# %%
print("SALGADO ZAMORANO GIBRAN ALEJANDRO 2SV1")
print("ax^2+bx+c=0")
print("Programa que diga si el discriminante tiene solución positiva")

a=int(input("Ingresa el valor de a "))
b=int(input("Ingresa el valor de b "))
c=int(input("Ingresa el valor de c "))
d=((b**2)-(4*a*c))
print("El valor de la discriminante es ", d)
while d<=0:
  print("Error, El valor de la discriminante debe ser positiva")
  a=int(input("Ingresa el valor de a "))
  b=int(input("Ingresa el valor de b "))
  c=int(input("Ingresa el valor de c "))
  d=((b**2)-(4*a*c))
print("El valor de la discriminante es ", d)
continue
# Out:
# SALGADO ZAMORANO GIBRAN ALEJANDRO 2SV1
# ax^2+bx+c=0
# Programa que diga si el discriminante tiene solución positiva
# Ingresa el valor de a 4
# Ingresa el valor de b 3
# Ingresa el valor de c 2
# El valor de la discriminante es  -23
# Error, El valor de la discriminante debe ser positiva
# Ingresa el valor de a 1
# Ingresa el valor de b 5
# Ingresa el valor de c 1
# El valor de la discriminante es  21
#   File "<ipython-input-28-f7ee91a81143>", line 17
#     continue
#             ^
# SyntaxError: 'continue' not properly in loop

# %% [markdown]
# Programa 2: F(x)=e^(-x)

# %%
e=2.7182818284
print("SALGADO ZAMORANO GIBRAN ALEJANDRO 2SV1")
print("f(x)=e^(-x)")
print("Evalua la función de -4 a 10 y guarda resultados en una lista")
lista=[]
print("Mi Lista", lista)
def solucion(x):
  funcion= (e**a)
  return funcion
a=-5
while a<10:
  a=a+1
  solucion(a)
  lista.append(solucion(a))
print("MI LISTA", lista)
# Out:
# SALGADO ZAMORANO GIBRAN ALEJANDRO 2SV1
# f(x)=e^(-x)
# Evalua la función de -4 a 10 y guarda resultados en una lista
# Mi Lista []
# MI LISTA [0.01831563889032556, 0.0497870683711083, 0.13533528324249208, 0.3678794411794332, 1.0, 2.7182818284, 7.389056098609647, 20.0855369218788, 54.59815002840041, 148.41315908645777, 403.4287934401565, 1096.6331582617145, 2980.9579865237197, 8103.083925991278, 22026.465790022223]
